# %% [markdown]
# Inverse Kinematics validation:
# (Try to run this code in VScode or pycharm to get a joint angles and circle at every instant)

# %%
#INVERSE KINEMATICS
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols,sin,cos,Matrix,pprint

a, d, alpha, theta, theta1, theta2, theta3, theta4, theta5, theta6,t = 
sp.symbols('a d alpha theta theta1 theta2 theta3 theta4 theta5 theta6 t')    

# Transformation matrix 
T = sp.Matrix([[sp.cos(theta), -sp.sin(theta)*sp.cos(alpha), sp.sin(theta)*sp.sin(alpha), a*sp.cos(theta)],
              [sp.sin(theta), sp.cos(theta)*sp.cos(alpha), -sp.cos(theta)*sp.sin(alpha), a*sp.sin(theta)],
              [0, sp.sin(alpha), sp.cos(alpha), d],
              [0, 0, 0, 1]])
print("The Transformation Matrix:")
pprint(T)
A1 = T.subs([(d, 0.089159), (a, 0), (alpha, sp.pi/2), (theta, theta1)])
print("\n")
pprint(A1)
T2 = T.subs([(d, 0), (a, -0.425), (alpha, 0), (theta, theta2)])
A2 = A1*T2
print("\n")
pprint(A2)
T3 = T.subs([(d, 0), (a, -0.39225), (alpha, 0), (theta, theta3)]) 
A3 = A1*T2*T3
print("\n")
pprint(A3)
T4 = T.subs([(d, 0.10915), (a, 0), (alpha, sp.pi/2), (theta, theta4)])
A4 = A1*T2*T3*T4
print("\n")
pprint(41)
T5 = T.subs([(d, 0.09465), (a, 0), (alpha, -sp.pi/2), (theta, theta5)])
A5 = A1*T2*T3*T4*T5
print("\n")
pprint(A5)
T6 = T.subs([(d, 0.0823), (a, 0), (alpha, 0), (theta, theta6)])
A6 = A1*T2*T3*T4*T5*T6
print("\n")
pprint(A6)

J = sp.Matrix([[sp.diff(A6[0,3],theta1),sp.diff(A6[0,3],theta2),sp.diff(A6[0,3],theta3),sp.diff(A6[0,3],theta4),sp.diff(A6[0,3],theta5),sp.diff(A6[0,3],theta6)],
               [sp.diff(A6[1,3],theta1),sp.diff(A6[1,3],theta2),sp.diff(A6[1,3],theta3),sp.diff(A6[1,3],theta4),sp.diff(A6[1,3],theta5),sp.diff(A6[1,3],theta6)],
               [sp.diff(A6[2,3],theta1),sp.diff(A6[2,3],theta2),sp.diff(A6[2,3],theta3),sp.diff(A6[2,3],theta4),sp.diff(A6[2,3],theta5),sp.diff(A6[2,3],theta6)],
               [A1[0,2],A2[0,2],A4[0,2],A5[0,2],A6[0,2],A6[0,2]],
               [A1[1,2],A2[1,2],A4[1,2],A5[1,2],A6[1,2],A6[1,2]],
               [A1[2,2],A2[2,2],A4[2,2],A5[2,2],A6[2,2],A6[2,2]]])
print("The Jacobian Matrix ")
pprint(J)

omega=(2*3.14)/5
dt=0.125
time = np.arange(0, 5, dt)

x_dot=sp.Matrix([[0],[omega*0.1*sp.cos(omega*t)],[-omega*0.1*sp.sin(omega*t)],[0],[0],[0]])

q=sp.Matrix([[sp.pi/2],[-sp.pi/2],[sp.pi/2],[-sp.pi],[-sp.pi/2],[0]])  

fig = plt.figure(figsize = (10, 10))         
ax = plt.axes(projection ="3d")
plt.title("End effector trajectory to draw the circle")
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(1,0)
ax.set_ylim(-0.5,0.5)
ax.set_zlim(0.4,1)
ax.set_xlabel('X -AXIS')
ax.set_ylabel('Y -AXIS')
ax.set_zlabel('Z -AXIS')

for i in range(0,40):
 #substituting the joint angles in final transformation matrix
    A6_x_y_z=A6.subs([(theta1, q[0]), (theta2, q[1]), (theta3, q[2]), (theta4, q[3]), (theta5, q[4]), (theta6, q[5])])       
    ax.scatter3D(A6_x_y_z[0,-1], A6_x_y_z[1,-1], A6_x_y_z[2,-1], color = "red")
    J_inv=J.subs([(theta1, q[0]), (theta2, q[1]), (theta3, q[2]), (theta4, q[3]), (theta5, q[4]), (theta6, q[5])])
    
    #taking jacobian inverse with current joint angles
    J_inv=(J_inv.evalf()).inv()                                                                
    
    X_ = x_dot.subs([(t,time[i])]).evalf()
    q_dot=(J_inv * X_).evalf()  
    q = q + q_dot *dt
    plt.pause(0.1)

plt.show()
# Out:
# The Transformation Matrix:
# ⎡cos(θ)  -sin(θ)⋅cos(α)  sin(α)⋅sin(θ)   a⋅cos(θ)⎤
# ⎢                                                ⎥
# ⎢sin(θ)  cos(α)⋅cos(θ)   -sin(α)⋅cos(θ)  a⋅sin(θ)⎥
# ⎢                                                ⎥
# ⎢  0         sin(α)          cos(α)         d    ⎥
# ⎢                                                ⎥
# ⎣  0           0               0            1    ⎦
#
#
# ⎡cos(θ₁)  0  sin(θ₁)      0    ⎤
# ⎢                              ⎥
# ⎢sin(θ₁)  0  -cos(θ₁)     0    ⎥
# ⎢                              ⎥
# ⎢   0     1     0      0.089159⎥
# ⎢                              ⎥
# ⎣   0     0     0         1    ⎦
#
#
# ⎡cos(θ₁)⋅cos(θ₂)  -sin(θ₂)⋅cos(θ₁)  sin(θ₁)    -0.425⋅cos(θ₁)⋅cos(θ₂) ⎤
# ⎢                                                                     ⎥
# ⎢sin(θ₁)⋅cos(θ₂)  -sin(θ₁)⋅sin(θ₂)  -cos(θ₁)   -0.425⋅sin(θ₁)⋅cos(θ₂) ⎥
# ⎢                                                                     ⎥
# ⎢    sin(θ₂)          cos(θ₂)          0      0.089159 - 0.425⋅sin(θ₂)⎥
# ⎢                                                                     ⎥
# ⎣       0                0             0                 1            ⎦
#
#
# ⎡-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)  -sin(θ₂)⋅cos(θ₁)⋅cos(θ₃)
# ⎢
# ⎢-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)  -sin(θ₁)⋅sin(θ₂)⋅cos(θ₃)
# ⎢
# ⎢        sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂)                   -sin(θ₂)⋅sin(θ₃)
# ⎢
# ⎣                        0                                                   0
#
# - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)  sin(θ₁)   0.39225⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - 0.39225
#
# - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)  -cos(θ₁)  0.39225⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - 0.39225
#
# + cos(θ₂)⋅cos(θ₃)             0            -0.39225⋅sin(θ₂)⋅cos(θ₃) - 0.425⋅si
#
#                               0
#
# ⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃) - 0.425⋅cos(θ₁)⋅cos(θ₂)⎤
#                                                 ⎥
# ⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃) - 0.425⋅sin(θ₁)⋅cos(θ₂)⎥
#                                                 ⎥
# n(θ₂) - 0.39225⋅sin(θ₃)⋅cos(θ₂) + 0.089159      ⎥
#                                                 ⎥
#    1                                            ⎦
#
#
# 41
#
#
# ⎡((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos
# ⎢
# ⎢((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin
# ⎢
# ⎢                         ((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (sin
# ⎢
# ⎣                                                                           0
#
# (θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) + sin(θ₁)⋅sin(θ₅)  -(
#
# (θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) - sin(θ₅)⋅cos(θ₁)  -(
#
# (θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅cos(θ₅)
#
#
#
# -sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₂)⋅cos(θ₁
#
# -sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₁)⋅sin(θ₂
#
#                (-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - (sin(θ₂)⋅cos(θ₃)
#
#                                                            0
#
# )⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄)  -((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + co
#
# )⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)  -((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + si
#
#  + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)                                            -((-sin
#
#
#
# s(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅c
#
# n(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅c
#
# (θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅
#
#                                            0
#
# os(θ₂))⋅sin(θ₄))⋅sin(θ₅) + sin(θ₁)⋅cos(θ₅)  0.09465⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁)
#
# os(θ₂))⋅sin(θ₄))⋅sin(θ₅) - cos(θ₁)⋅cos(θ₅)  0.09465⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
# cos(θ₄))⋅sin(θ₅)                                                           -0.
#
#
#
# + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.09465⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ
#
# + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.09465⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ
#
# 09465⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + 0.09465⋅(sin(θ₂)⋅cos(θ₃)
#
#
#
# ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄) + 0.10915⋅sin(θ₁) + 0.39225⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁
#
# ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) + 0.39225⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - 0.39225⋅sin(θ₁
#
# + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄) - 0.39225⋅sin(θ₂)⋅cos(θ₃) - 0.425⋅sin(θ₂) - 0.39225
#
#             1
#
# ) - 0.39225⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃) - 0.425⋅cos(θ₁)⋅cos(θ₂)⎤
#                                                            ⎥
# )⋅cos(θ₂)⋅cos(θ₃) - 0.425⋅sin(θ₁)⋅cos(θ₂) - 0.10915⋅cos(θ₁)⎥
#                                                            ⎥
# ⋅sin(θ₃)⋅cos(θ₂) + 0.089159                                ⎥
#                                                            ⎥
#                                                            ⎦
#
#
# ⎡(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅co
# ⎢
# ⎢(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅si
# ⎢
# ⎢                                           ((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ
# ⎢
# ⎣
#
# s(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) + sin(θ₁)⋅sin(θ₅))⋅c
#
# n(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) - sin(θ₅)⋅cos(θ₁))⋅c
#
# ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅cos(θ₅)⋅cos(θ₆) + (
#
#                                                                        0
#
# os(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-si
#
# os(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-si
#
# (-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(
#
#
#
# n(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₆)  -(((-sin(θ₂
#
# n(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₆)  -(((-sin(θ₁
#
# θ₂))⋅sin(θ₄))⋅sin(θ₆)
#
#
#
# )⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ
#
# )⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ
#
#                                 -((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄)
#
#
#
# ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) + sin(θ₁)⋅sin(θ₅))⋅sin(θ₆) + (-
#
# ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) - sin(θ₅)⋅cos(θ₁))⋅sin(θ₆) + (-
#
#  + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₆)⋅cos(θ₅) + ((-sin(θ₂)⋅s
#
#                                                             0
#
# (-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₂)⋅cos(θ
#
# (-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₁)⋅sin(θ
#
# in(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄
#
#
#
# ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄))⋅cos(θ₆)  -((-sin(θ₂)⋅sin(θ₃)⋅co
#
# ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅cos(θ₆)  -((-sin(θ₁)⋅sin(θ₂)⋅si
#
# ))⋅cos(θ₆)
#
#
#
# s(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)
#
# n(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)
#
#    -((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)
#
#                                                      0
#
# ⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + sin(θ₁)⋅cos(θ₅)  -0.0823⋅((-sin(θ₂)⋅sin(θ
#
# ⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) - cos(θ₁)⋅cos(θ₅)  -0.0823⋅((-sin(θ₁)⋅sin(θ
#
# ⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅)
#
#
#
# ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - si
#
# ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - si
#
#                                      -0.0823⋅((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(
#
#
#
# n(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + 0.09465⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) +
#
# n(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + 0.09465⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) +
#
# θ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) - 0.09465⋅
#
#
#
# cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.09465⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)
#
# sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.09465⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)
#
# (-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + 0.09465⋅(sin(θ₂)⋅cos(θ₃) + sin(
#
#                             1
#
# ⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄) + 0.0823⋅sin(θ₁)⋅cos(θ₅) + 0.10915⋅sin(θ₁) + 0.39225
#
# ⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) + 0.39225⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - 0.39225⋅sin(θ₁)⋅
#
# θ₃)⋅cos(θ₂))⋅sin(θ₄) - 0.39225⋅sin(θ₂)⋅cos(θ₃) - 0.425⋅sin(θ₂) - 0.39225⋅sin(θ
#
#
#
# ⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - 0.39225⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃) - 0.425⋅cos(θ₁)⋅cos
#
# cos(θ₂)⋅cos(θ₃) - 0.425⋅sin(θ₁)⋅cos(θ₂) - 0.0823⋅cos(θ₁)⋅cos(θ₅) - 0.10915⋅cos
#
# ₃)⋅cos(θ₂) + 0.089159
#
#
#
# (θ₂)⎤
#     ⎥
# (θ₁)⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎦
# The Jacobian Matrix
# ⎡ (-0.0823⋅(sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - 0.082
# ⎢
# ⎢(-0.0823⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - 0.082
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
# 3⋅(sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + (0.09
#
# 3⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + (-0.
#
#
#
#
#
#
#
#
#
# 465⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - 0.09465⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-0.0
#
# 09465⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + 0.09465⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (0.
#
#                                                                 0
#
#                                                              sin(θ₁)
#
#                                                              -cos(θ₁)
#
#                                                                 0
#
# 9465⋅sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - 0.09465⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) - 0.39
#
# 09465⋅sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + 0.09465⋅sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄) + 0.0
#
#
#
#
#
#
#
#
#
# 225⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + 0.39225⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃) + 0.425⋅sin(θ₁)⋅
#
# 823⋅sin(θ₁)⋅cos(θ₅) + 0.10915⋅sin(θ₁) + 0.39225⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - 0.39
#
#
#
#
#
#
#
#
#
# cos(θ₂) + 0.0823⋅cos(θ₁)⋅cos(θ₅) + 0.10915⋅cos(θ₁)   (-0.0823⋅(sin(θ₂)⋅sin(θ₃)
#
# 225⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃) - 0.425⋅cos(θ₁)⋅cos(θ₂)  (-0.0823⋅(sin(θ₁)⋅sin(θ₂)
#
#
#
#
#
#
#
#
#
# ⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃)
#
# ⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃)
#
#                    (-0.0823⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - 0.0
#
#
#
#
#
#
#
#  - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ
#
#  - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ
#
# 823⋅(-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₂)⋅
#
#
#
#
#
#
#
# ₁) + 0.09465⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-0.09465⋅sin(θ₂)⋅cos(θ₁)⋅cos(
#
# ₃) + 0.09465⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-0.09465⋅sin(θ₁)⋅sin(θ₂)⋅cos(
#
# sin(θ₃) + 0.09465⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (0.09465⋅sin(θ₂)⋅cos(θ₃) + 0.0946
#
#               sin(θ₁)
#
#              -cos(θ₁)
#
#                  0
#
# θ₃) - 0.09465⋅sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄) + 0.39225⋅sin(θ₂)⋅cos(θ₁)⋅cos(θ
#
# θ₃) - 0.09465⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄) + 0.39225⋅sin(θ₁)⋅sin(θ₂)⋅cos(θ
#
# 5⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) + 0.39225⋅sin(θ₂)⋅sin(θ₃) - 0.39225⋅cos(θ₂)⋅cos(θ₃)
#
#
#
#
#
#
#
# ₃) + 0.425⋅sin(θ₂)⋅cos(θ₁) + 0.39225⋅sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)  (-0.0823⋅(sin(θ₂
#
# ₃) + 0.425⋅sin(θ₁)⋅sin(θ₂) + 0.39225⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)  (-0.0823⋅(sin(θ₁
#
#  - 0.425⋅cos(θ₂)
#
#
#
#
#
#
#
# )⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(-sin(θ₂)⋅cos(θ₁
#
# )⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(-sin(θ₁)⋅sin(θ₂
#
#                         (-0.0823⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄)
#
#
#
#
#
#
#
# )⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₂)⋅sin(
#
# )⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₁)⋅sin(
#
# - 0.0823⋅(-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + (-0.09465⋅sin
#
#                                (-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos
#
#                                (-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos
#
#                                                -(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅co
#
# θ₃)⋅cos(θ₁) + 0.09465⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-0.09465⋅sin(θ₂)⋅cos
#
# θ₂)⋅sin(θ₃) + 0.09465⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-0.09465⋅sin(θ₁)⋅sin
#
# (θ₂)⋅sin(θ₃) + 0.09465⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (0.09465⋅sin(θ₂)⋅cos(θ₃) + 0
#
# (θ₃))⋅sin(θ₄) - (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄)
#
# (θ₃))⋅sin(θ₄) - (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)
#
# s(θ₃))⋅cos(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)
#
# (θ₁)⋅cos(θ₃) - 0.09465⋅sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄) + 0.39225⋅sin(θ₂)⋅cos(
#
# (θ₂)⋅cos(θ₃) - 0.09465⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄) + 0.39225⋅sin(θ₁)⋅sin(
#
# .09465⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) + 0.39225⋅sin(θ₂)⋅sin(θ₃) - 0.39225⋅cos(θ₂)⋅co
#
#
#
#
#
#
#
# θ₁)⋅cos(θ₃) + 0.39225⋅sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)  (0.0823⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ
#
# θ₂)⋅cos(θ₃) + 0.39225⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)  (0.0823⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ
#
# s(θ₃)
#
#
#
#
#
#
#
# ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin
#
# ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin
#
#  (-0.0823⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + 0.0823⋅(sin(θ₂)⋅cos(θ
#
#                                              -((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos
#
#                                              -((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin
#
#                                                                       -((-sin(
#
# (θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + 0
#
# (θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅) + (-0.09465⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + 0
#
# ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) - (0.09465⋅sin(θ₂)⋅sin(θ₃) - 0.09465⋅co
#
# (θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅co
#
# (θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅co
#
# θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅c
#
# .09465⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - (0.09465⋅sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + 0
#
# .09465⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - (0.09465⋅sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + 0
#
# s(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (0.09465⋅sin(θ₂)⋅cos(θ₃) + 0.09465⋅sin(θ₃)⋅cos(θ₂))⋅c
#
# s(θ₂))⋅sin(θ₄))⋅sin(θ₅) + sin(θ₁)⋅cos(θ₅)
#
# s(θ₂))⋅sin(θ₄))⋅sin(θ₅) - cos(θ₁)⋅cos(θ₅)
#
# os(θ₄))⋅sin(θ₅)
#
# .09465⋅sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄)  (-0.0823⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) +
#
# .09465⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)  (-0.0823⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) +
#
# os(θ₄)                                                                (-0.0823
#
#                                                    -((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁)
#
#                                                    -((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
#                                                                              -
#
# cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - 0.0823⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅
#
# sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - 0.0823⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅
#
# ⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - 0.0823⋅(sin(θ₂)⋅cos(θ₃) + sin(
#
#  + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(
#
#  + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(
#
# ((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos
#
# cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) - 0.0823⋅sin(θ₁)⋅sin(θ₅)
#
# sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅cos(θ₅) + 0.0823⋅sin(θ₅)⋅cos(θ₁)
#
# θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅cos(θ₅)
#
# θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + sin(θ₁)⋅cos(θ₅)             -((-sin(θ₂)⋅sin(θ₃
#
# θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) - cos(θ₁)⋅cos(θ₅)             -((-sin(θ₁)⋅sin(θ₂
#
# (θ₂))⋅cos(θ₄))⋅sin(θ₅)
#
#                                                          0
#
#                                                          0
#
#                                                          0
#
# )⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin
#
# )⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin
#
#        -((-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin
#
#                                                         ⎤
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
# (θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) + sin(θ₁)⋅cos(θ₅)⎥
#                                                         ⎥
# (θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₄))⋅sin(θ₅) - cos(θ₁)⋅cos(θ₅)⎥
#                                                         ⎥
# (θ₃)⋅cos(θ₂))⋅cos(θ₄))⋅sin(θ₅)                          ⎦
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-96e3466e13fd> in <module>
#      77     q = q + q_dot *dt
#      78
# ---> 79     plt.pause(0.1)
#      80
#      81 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in pause(interval)
#     309         canvas = manager.canvas
#     310         if canvas.figure.stale:
# --> 311             canvas.draw_idle()
#     312         show(block=False)
#     313         canvas.start_event_loop(interval)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1945         if not self._is_idle_drawing:
#    1946             with self._idle_draw_cntx():
# -> 1947                 self.draw(*args, **kwargs)
#    1948
#    1949     @cbook.deprecated("3.2")
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1733
#    1734             self.patch.draw(renderer)
# -> 1735             mimage._draw_list_compositing_images(
#    1736                 renderer, self, artists, self.suppressComposite)
#    1737
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     289                             for axis in self._get_axis_list()) + 1
#     290         for i, col in enumerate(
# --> 291                 sorted(self.collections,
#     292                        key=lambda col: col.do_3d_projection(renderer),
#     293                        reverse=True)):
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py in <lambda>(col)
#     290         for i, col in enumerate(
#     291                 sorted(self.collections,
# --> 292                        key=lambda col: col.do_3d_projection(renderer),
#     293                        reverse=True)):
#     294             col.zorder = zorder_offset + i
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/art3d.py in do_3d_projection(self, renderer)
#     540         fcs = (_zalpha(self._facecolor3d, vzs) if self._depthshade else
#     541                self._facecolor3d)
# --> 542         fcs = mcolors.to_rgba_array(fcs, self._alpha)
#     543         self.set_facecolors(fcs)
#     544
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     338         return np.zeros((0, 4), float)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#     342
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in <listcomp>(.0)
#     338         return np.zeros((0, 4), float)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#     342
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     183         rgba = None
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 185         rgba = _to_rgba_no_colorcycle(c, alpha)
#     186         try:
#     187             _colors_full_map.cache[c, alpha] = rgba
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     266         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     267         # Test dimensionality to reject single floats.
# --> 268         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     269     # Return a tuple to prevent the cached value from being modified.
#     270     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: masked_array(data=[1.0, 0.0, 0.0, 1.0],
#              mask=False,
#        fill_value='?',
#             dtype=object)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2098                            else suppress())
#    2099                     with ctx:
# -> 2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1733
#    1734             self.patch.draw(renderer)
# -> 1735             mimage._draw_list_compositing_images(
#    1736                 renderer, self, artists, self.suppressComposite)
#    1737
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     289                             for axis in self._get_axis_list()) + 1
#     290         for i, col in enumerate(
# --> 291                 sorted(self.collections,
#     292                        key=lambda col: col.do_3d_projection(renderer),
#     293                        reverse=True)):
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py in <lambda>(col)
#     290         for i, col in enumerate(
#     291                 sorted(self.collections,
# --> 292                        key=lambda col: col.do_3d_projection(renderer),
#     293                        reverse=True)):
#     294             col.zorder = zorder_offset + i
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/art3d.py in do_3d_projection(self, renderer)
#     540         fcs = (_zalpha(self._facecolor3d, vzs) if self._depthshade else
#     541                self._facecolor3d)
# --> 542         fcs = mcolors.to_rgba_array(fcs, self._alpha)
#     543         self.set_facecolors(fcs)
#     544
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     338         return np.zeros((0, 4), float)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#     342
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in <listcomp>(.0)
#     338         return np.zeros((0, 4), float)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#     342
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     183         rgba = None
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 185         rgba = _to_rgba_no_colorcycle(c, alpha)
#     186         try:
#     187             _colors_full_map.cache[c, alpha] = rgba
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     266         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     267         # Test dimensionality to reject single floats.
# --> 268         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     269     # Return a tuple to prevent the cached value from being modified.
#     270     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: masked_array(data=[1.0, 0.0, 0.0, 1.0],
#              mask=False,
#        fill_value='?',
#             dtype=object)
